# %%
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt

from fun import *

# %%
#Import data from CSV:

data = pd.read_csv('../ALL_twitter_accounts.csv')
data.head()
# Out:
#                            Nombre         Ocupación  \
# 0                  Unidas Podemos  Partido Político
# 1                            PSOE  Partido Político
# 2                 Izquierda Unida  Partido Político
# 3                Anticapitalistas  Partido Político
# 4  Santuario Animal Almas veganas        Asociación
#
#                        Afiliación  Izda          Twitter
# 0                         Podemos     1         @PODEMOS
# 1                            PSOE     1            @PSOE
# 2                              IU     1  @IzquierdaUnida
# 3                Anticapitalistas     1        @anticapi
# 4  Santuario Animal Almas veganas     1    @AlmasVeganas

# %%
df_train, df_val = validation_split(data)

OUT_FOLDER = '../0_DATA/'
df_train.to_csv( OUT_FOLDER + 'train-test_accounts.csv', index=False)
df_val.to_csv( OUT_FOLDER + 'val_accounts.csv', index=False)

# %%
#This dictionary contains the twitter accounts as keys and 0 or 1 as value
classification = data.set_index('Twitter')['Izda'].to_dict()

accounts_train = df_train['Twitter']
accounts_val = df_val['Twitter']

# %%
tweets_train, failed = import_tweets_from_list(list(accounts_train))

print('\n')
if(failed == []):
    print('All it is fine')
else:
    print('It have failed: ', failed)
# Out:
# Completed: @PODEMOS
# Completed: @AlmasVeganas
# Completed: @carmencalvo_
# Completed: @ierrejon
# Completed: @AdaColau
# Completed: @TeresaRodr_
# Completed: @RobertoVaquero_
# Completed: @quiquepeinado
# Completed: @AntonioMaestre
# Completed: @AlanBarrosoA
# Completed: @Barbijaputa
# Completed: @Nega_Maiz
# Completed: @IrantzuVarela
# Completed: @RubenSanchezTW
# Completed: @noepmp
# Completed: @populares
# Completed: @fedelasjons
# Completed: @HogarSocial_
# Completed: @ivanedlm
# Rate limit reached. Sleeping for: 178
# Completed: @Macarena_Olona
# Completed: @pablocasado_
# Completed: @anapastorjulian
# Completed: @sorayasds
# Completed: @JuanMa_Moreno
# Completed: @AlmeidaPP_
# Completed: @pacomarhuenda
# Completed: @alvaroojeda80
# ERROR: @LibertadSurja
# Completed: @MelisaDRuiz
# Completed: @janogarcia_
# Completed: @EsperanzAguirre
# Completed: @Gato_directo
# Completed: @okdiario
# Completed: @romancendoya
# Completed: @HorcajoXavier
# Completed: @javiernegre10
# Completed: @IzquierdaUnida
# Completed: @IreneMontero
# Completed: @TaniaSanchez_M
# Completed: @NicolasMaduro
# Completed: @_anapastor_
# Completed: @PabloHasel
# Completed: @publico_es
# Completed: @henarconh
# Completed: @hazteoir
# Completed: @MeerRocio
# Completed: @AlevySoler
# Completed: @IdiazAyuso
# Completed: @dlacalle
# ERROR: @cakealatake
# ERROR: @LibertadSurja
# Completed: @wallstwolverine
# Completed: @PresentadorGato
# Completed: @GarciaSerranoE
# Completed: @AlfonsoRojoPD
# Completed: @sanchezcastejon
# Completed: @edugaresp
# Completed: @masademocrata
# Completed: @gerardotc
# Completed: @Santi_ABASCAL
# Completed: @marianorajoy
# Completed: @eduardoinda
# ERROR: @LibertadSurja
# Completed: @JHS_Oficial
# Completed: @kikomonasterio
# Completed: @ManuelaCarmena
# Completed: @ToniMejiasM
# Completed: @cayetanaAT
# ERROR: @cakealatake
# ERROR: @LibertadSurja
# Completed: @larazon_es
# Completed: @FacuDiazT
# ERROR: @FeijooGalicia
# ERROR: @cakealatake
# ERROR: @LibertadSurja
# Completed: @vox_es
# ERROR: @cakealatake
# ERROR: @LibertadSurja
# ERROR: @FeijooGalicia
# ERROR: @cakealatake
# ERROR: @LibertadSurja
# ERROR: @FeijooGalicia
# ERROR: @cakealatake
# ERROR: @LibertadSurja
# ERROR: @FeijooGalicia
# ERROR: @cakealatake
# ERROR: @LibertadSurja
# ERROR: @FeijooGalicia
# ERROR: @cakealatake
# ERROR: @LibertadSurja
# Elapsed in 16.01188535 min
#
#
# It have failed:  ['@FeijooGalicia', '@cakealatake', '@LibertadSurja']

# %%
tweets_val, failed = import_tweets_from_list(list(accounts_val))

print('\n')
if(failed == []):
    print('All it is fine!')
else:
    print('It have failed: ', failed)
# Out:
# Completed: @PSOE
# Completed: @JosepBorrellF
# Completed: @PabloEchenique
# Completed: @AntonioMaestre
# Completed: @chavezcandanga
# Completed: @cuellilargo
# Completed: @eleonsuarez
# Completed: @Ortega_Smith
# Completed: @ManuelAndrino
# Completed: @anticapi
# Completed: @MonederoJC
# Completed: @SanchezGordillo
# Rate limit reached. Sleeping for: 149
# Completed: @manuelburque
# Completed: @juanrallo
# Completed: @PabloIglesias
# Completed: @diasextoreturns
# Completed: @agarzon
# Completed: @monasterioR
# Elapsed in 7.073630616666667 min
# All it is fine!

# %%
OUT_FOLDER = '../0_DATA/'

path = OUT_FOLDER + 'train-test_tweets.csv'
df_train = list_to_csv(tweets_train, classification, path)

path = OUT_FOLDER + 'val_tweets.csv'
df_val = list_to_csv(tweets_val, classification, path)

# %%
df_val
# Out:
#               User                                              Tweet  Left
# 0            @PSOE  vamos a construir y seguir construyendo andalu...     1
# 1            @PSOE  el pp quiere volver al modelo del "sálvese qui...     1
# 2            @PSOE  el bloqueo del cgpj es una anormalidad democrá...     1
# 3            @PSOE  el compromiso del gobierno es prorrogar el pla...     1
# 4            @PSOE  frente a los gobiernos del pp que optaron en s...     1
# ...            ...                                                ...   ...
# 2855  @monasterioR  el pleno del cgpj aprueba por unanimidad el in...     0
# 2856  @monasterioR  ¡enhorabuena @carlospollan ! 😘 https://t.co/mx...     0
# 2857  @monasterioR                        👏👏👏 https://t.co/smvmra6rze     0
# 2858  @monasterioR  ¡enhorabuena a @juan_ggallardo y a todo el equ...     0
# 2859  @monasterioR  ¡qué mal día tienen hoy los progres! 😂😂\n#solo...     0
#
# [2860 rows x 3 columns]
