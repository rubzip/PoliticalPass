# %%
import pandas as pd
import numpy as np
import pickle

# %%
#First step is to load the 
df_dictionary = pd.read_csv('df_freq.csv')

#We are going to take the n_max most frequent words:
n_max = 2000

df_dictionary = df_dictionary[:n_max]
df_dictionary
# Out:
#                Word  Frequency
# 0                 y       4503
# 1                 a       3956
# 2               the        981
# 3                to        743
# 4               and        622
# ...             ...        ...
# 1995  productividad          8
# 1996        welcome          8
# 1997          unity          8
# 1998           cabo          8
# 1999      elections          8
#
# [2000 rows x 2 columns]

# %%
#We are going to make a dictionary using Word as a key and index as values

df_dictionary = df_dictionary.reset_index()
df_dictionary = df_dictionary.set_index(keys='Word')
df_dictionary
# Out:
#                index  Frequency
# Word
# y                  0       4503
# a                  1       3956
# the                2        981
# to                 3        743
# and                4        622
# ...              ...        ...
# productividad   1995          8
# welcome         1996          8
# unity           1997          8
# cabo            1998          8
# elections       1999          8
#
# [2000 rows x 2 columns]

# %%
#THIS IS THE MOST IMPORTANT FILE IN PROGRAM ---> 'dictionary.json'
aux = df_dictionary['index']
dictionary = aux.to_dict()

with open('dictionary.json', 'w') as f:
    json.dump(dictionary, f)
