# %%
import pandas as pd
import numpy as np
import pickle
import json

# %%
df_data = pd.read_csv('tokenized.csv')

with open('dictionary.json') as json_file:
    dictionary = json.load(json_file)

dictionary
# Out:
# {'y': 0,
#  'a': 1,
#  'España': 2,
#  'o': 3,
#  'año': 4,
#  'Madrid': 5,
#  'Gobierno': 6,
#  'seguir': 7,
#  'español': 8,
#  'the': 9,
#  'Sánchez': 10,
#  'gracias': 11,
#  'to': 12,
#  'dejar': 13,
#  'país': 14,
#  'querer': 15,
#  'e': 16,
#  'vida': 17,
#  'and': 18,
#  'mujer': 19,
#  'poder': 20,
#  'público': 21,
#  'persona': 22,
#  'ver': 23,
#  'i': 24,
#  'PP': 25,
#  'estar': 26,
#  'gobierno': 27,
#  'derecho': 28,
#  'of': 29,
#  'haber': 30,
#  'tener': 31,
#  'hablar': 32,
#  'defender': 33,
#  'gente': 34,
#  'pedir': 35,
#  'volver': 36,
#  'familia': 37,
#  'pasar': 38,
#  'llegar': 39,
#  'político': 40,
#  'apoyo': 41,
#  'salir': 42,
#  'política': 43,
#  'decir': 44,
#  'social': 45,
#  'libertad': 46,
#  'poner': 47,
#  'vivir': 48,
#  'millón': 49,
#  'mundo': 50,
#  'in': 51,
#  'hacer': 52,
#  'ley': 53,
#  'mañana': 54,
#  'gracia': 55,
#  'pueblo': 56,
#  'esperar': 57,
#  'acabar': 58,
#  'frente': 59,
#  'deber': 60,
#  'quedar': 61,
#  'violencia': 62,
#  'problema': 63,
#  'luz': 64,
#  'pandemia': 65,
#  'impuesto': 66,
#  'precio': 67,
#  'Andalucía': 68,
#  'venir': 69,
#  'necesitar': 70,
#  'directo': 71,
#  'partido': 72,
#  'democracia': 73,
#  'feliz': 74,
#  'futuro': 75,
#  'pagar': 76,
#  'derecha': 77,
#  'ganar': 78,
#  'dar': 79,
#  'sociedad': 80,
#  'historia': 81,
#  'mes': 82,
#  'proyecto': 83,
#  'empezar': 84,
#  'EU': 85,
#  'on': 86,
#  'PSOE': 87,
#  'ciudad': 88,
#  'económico': 89,
#  'lucha': 90,
#  'per': 91,
#  'presidente': 92,
#  'izquierda': 93,
#  'cumplir': 94,
#  'llevar': 95,
#  'cambio': 96,
#  'importante': 97,
#  'semana': 98,
#  'casa': 99,
#  'Europa': 100,
#  'servicio': 101,
#  'empresa': 102,
#  'with': 103,
#  'calle': 104,
#  'trabajador': 105,
#  'entender': 106,
#  'avanzar': 107,
#  'Afganistán': 108,
#  'for': 109,
#  'entrevista': 110,
#  'ir': 111,
#  'abrazo': 112,
#  'crisis': 113,
#  'perder': 114,
#  'votar': 115,
#  'recordar': 116,
#  'apoyar': 117,
#  'permitir': 118,
#  'medio': 119,
#  'compromiso': 120,
#  'creer': 121,
#  'medida': 122,
#  'único': 123,
#  'campaña': 124,
#  'dinero': 125,
#  'contar': 126,
#  'pensar': 127,
#  'forma': 128,
#  'situación': 129,
#  'madrileño': 130,
#  'sistema': 131,
#  'A': 132,
#  'recuperación': 133,
#  'elección': 134,
#  'vídeo': 135,
#  'recibir': 136,
#  'hombre': 137,
#  'solidaridad': 138,
#  'equipo': 139,
#  'llamar': 140,
#  'ayudar': 141,
#  'salud': 142,
#  'artículo': 143,
#  'sanitario': 144,
#  'trabajar': 145,
#  'caso': 146,
#  'explicar': 147,
#  'víctima': 148,
#  'Galicia': 149,
#  'enhorabuena': 150,
#  'sufrir': 151,
#  'realidad': 152,
#  'leer': 153,
#  'feminista': 154,
#  'mano': 155,
#  'Y': 156,
#  'indulto': 157,
#  'subir': 158,
#  'niño': 159,
#  'celebrar': 160,
#  'compartir': 161,
#  'machista': 162,
#  'construir': 163,
#  'necesario': 164,
#  'histórico': 165,
#  'animal': 166,
#  'unidad': 167,
#  'presentar': 168,
#  'UE': 169,
#  'joven': 170,
#  'colaborar': 171,
#  'is': 172,
#  'amigo': 173,
#  'vecino': 174,
#  'recuperar': 175,
#  'proteger': 176,
#  'odio': 177,
#  'bajar': 178,
#  'Congreso': 179,
#  'andaluz': 180,
#  'economía': 181,
#  'luchar': 182,
#  'tomar': 183,
#  'sector': 184,
#  'VOX': 185,
#  'interés': 186,
#  'acto': 187,
#  'garantizar': 188,
#  'cultura': 189,
#  'exigir': 190,
#  'ser': 191,
#  'oportunidad': 192,
#  'vía': 193,
#  'mil': 194,
#  'noticia': 195,
#  'europeo': 196,
#  'centro': 197,
#  'cambiar': 198,
#  'Venezuela': 199,
#  'seguro': 200,
#  'vacunación': 201,
#  'justicia': 202,
#  'paso': 203,
#  'M': 204,
#  'gustar': 205,
#  'objetivo': 206,
#  'hijo': 207,
#  'aprobar': 208,
#  'ciudadano': 209,
#  'mantener': 210,
#  'internacional': 211,
#  'juez': 212,
#  'gobernar': 213,
#  'mirar': 214,
#  'fuerza': 215,
#  'buscar': 216,
#  'libre': 217,
#  'cariño': 218,
#  'mercado': 219,
#  'palabra': 220,
#  'merecer': 221,
#  'orgullo': 222,
#  'mensaje': 223,
#  'demostrar': 224,
#  'abrir': 225,
#  'disfrutar': 226,
#  'nacional': 227,
#  'favor': 228,
#  'Ley': 229,
#  'ayuda': 230,
#  'entrar': 231,
#  'Comunidad': 232,
#  'mejorar': 233,
#  'esfuerzo': 234,
#  'camino': 235,
#  'crear': 236,
#  'fuerte': 237,
#  'amp': 238,
#  'escuchar': 239,
#  'idea': 240,
#  'recurso': 241,
#  'fondo': 242,
#  'comunidad': 243,
#  'institución': 244,
#  'compañero': 245,
#  'Barcelona': 246,
#  'sentir': 247,
#  'participar': 248,
#  'encontrar': 249,
#  'elegir': 250,
#  'querido': 251,
#  'dato': 252,
#  'mayoría': 253,
#  'vacuna': 254,
#  'factura': 255,
#  'barrio': 256,
#  'we': 257,
#  'solución': 258,
#  'defensa': 259,
#  'Ayuso': 260,
#  'energía': 261,
#  'sacar': 262,
#  'orgulloso': 263,
#  'libro': 264,
#  'alguien': 265,
#  'euros': 266,
#  'Cataluña': 267,
#  'noche': 268,
#  'Pedro': 269,
#  'memoria': 270,
#  'petición': 271,
#  'cosa': 272,
#  'justo': 273,
#  'saber': 274,
#  'responsabilidad': 275,
#  'seguridad': 276,
#  'our': 277,
#  'Pablo': 278,
#  'ministro': 279,
#  'asesinato': 280,
#  'tanto': 281,
#  'plan': 282,
#  'pensión': 283,
#  'menor': 284,
#  'junto': 285,
#  'agradecer': 286,
#  'conocer': 287,
#  'olvidar': 288,
#  'falta': 289,
#  'convertir': 290,
#  'cuidar': 291,
#  'verano': 292,
#  'igualdad': 293,
#  'programa': 294,
#  'propuesta': 295,
#  'espacio': 296,
#  'FIRMA': 297,
#  'honor': 298,
#  'Cuba': 299,
#  'gestión': 300,
#  'autónomo': 301,
#  'amb': 302,
#  'completo': 303,
#  'vivienda': 304,
#  'reconocer': 305,
#  'tierra': 306,
#  'profesional': 307,
#  'debate': 308,
#  'm': 309,
#  'tema': 310,
#  'alto': 311,
#  'mayo': 312,
#  'climático': 313,
#  'el': 314,
#  'especial': 315,
#  'firmar': 316,
#  'difícil': 317,
#  'colectivo': 318,
#  'caer': 319,
#  'visitar': 320,
#  'foto': 321,
#  'evitar': 322,
#  'lograr': 323,
#  'Constitución': 324,
#  'padre': 325,
#  'democrático': 326,
#  'servir': 327,
#  'santuario': 328,
#  'proponer': 329,
#  'extremo': 330,
#  'Patria': 331,
#  'clase': 332,
#  'fiscal': 333,
#  'subida': 334,
#  'punto': 335,
#  'nombre': 336,
#  'jugar': 337,
#  'tipo': 338,
#  'voto': 339,
#  'reducir': 340,
#  'The': 341,
#  'género': 342,
#  'privado': 343,
#  'Vox': 344,
#  'máximo': 345,
#  'denunciar': 346,
#  'obra': 347,
#  'generar': 348,
#  'muerte': 349,
#  'mandar': 350,
#  'común': 351,
#  'escribir': 352,
#  'negar': 353,
#  'mejor': 354,
#  'Ceuta': 355,
#  'do': 356,
#  'real': 357,
#  'crecer': 358,
#  'necesidad': 359,
#  'periodista': 360,
#  'importar': 361,
#  'comenzar': 362,
#  'población': 363,
#  'José': 364,
#  'medalla': 365,
#  'homenaje': 366,
#  'educación': 367,
#  'paro': 368,
#  'impulsar': 369,
#  'reforma': 370,
#  'faltar': 371,
#  'modelo': 372,
#  'esperanza': 373,
#  'grande': 374,
#  'Viva': 375,
#  'atacar': 376,
#  'Gracias': 377,
#  'miedo': 378,
#  'fundamental': 379,
#  'personal': 380,
#  'comprar': 381,
#  'éxito': 382,
#  'Casado': 383,
#  'reparto': 384,
#  'discurso': 385,
#  'tocar': 386,
#  'humano': 387,
#  'Ayuntamiento': 388,
#  'respuesta': 389,
#  'beneficio': 390,
#  'beso': 391,
#  'unir': 392,
#  'Juan': 393,
#  'LaEspañaQueHacemos': 394,
#  'fascismo': 395,
#  'grupo': 396,
#  'zona': 397,
#  'placer': 398,
#  'intervención': 399,
#  'matar': 400,
#  'decisión': 401,
#  'pretender': 402,
#  'enorme': 403,
#  'clave': 404,
#  'razón': 405,
#  'red': 406,
#  'salvar': 407,
#  'atención': 408,
#  'sentido': 409,
#  'reto': 410,
#  'as': 411,
#  'cara': 412,
#  'madre': 413,
#  'decidir': 414,
#  'global': 415,
#  'pleno': 416,
#  'mentira': 417,
#  'Kabul': 418,
#  'valor': 419,
#  'aumentar': 420,
#  'minuto': 421,
#  'Tribunal': 422,
#  'sanidad': 423,
#  'mínimo': 424,
#  'oposición': 425,
#  'calidad': 426,
#  'producto': 427,
#  'Nacional': 428,
#  'agenda': 429,
#  'labor': 430,
#  'et': 431,
#  'cerrar': 432,
#  'dictadura': 433,
#  'mostrar': 434,
#  'my': 435,
#  'aceptar': 436,
#  'reconocimiento': 437,
#  'paz': 438,
#  'nivel': 439,
#  'cumpleaños': 440,
#  'maravilloso': 441,
#  'apostar': 442,
#  'gasto': 443,
#  'utilizar': 444,
#  'momento': 445,
#  'malo': 446,
#  'echar': 447,
#  'policía': 448,
#  'victoria': 449,
#  'cuestión': 450,
#  'ofrecer': 451,
#  'deporte': 452,
#  'morir': 453,
#  'laboral': 454,
#  'marcha': 455,
#  'corazón': 456,
#  'superar': 457,
#  'EEUU': 458,
#  'formar': 459,
#  'respeto': 460,
#  'diálogo': 461,
#  'canal': 462,
#  'feminismo': 463,
#  'suerte': 464,
#  'LGTBI': 465,
#  'Justicia': 466,
#  'comer': 467,
#  'San': 468,
#  'representar': 469,
#  'récord': 470,
#  'responder': 471,
#  'mayor': 472,
#  'valer': 473,
#  'hora': 474,
#  'resto': 475,
#  'sumar': 476,
#  'inmigrante': 477,
#  'tuit': 478,
#  'catalán': 479,
#  'bandera': 480,
#  'més': 481,
#  'digno': 482,
#  'alternativa': 483,
#  'capacidad': 484,
#  'proceso': 485,
#  'valiente': 486,
#  'salario': 487,
#  'talibán': 488,
#  'compañera': 489,
#  'jornada': 490,
#  'reunión': 491,
#  'culpa': 492,
#  'niña': 493,
#  'alcanzar': 494,
#  'suponer': 495,
#  'socialista': 496,
#  'frenar': 497,
#  'inversión': 498,
#  'funcionar': 499,
#  'control': 500,
#  'cobrar': 501,
#  'verde': 502,
#  'cultural': 503,
#  'electoral': 504,
#  'fascista': 505,
#  'condición': 506,
#  'domingo': 507,
#  'afgano': 508,
#  'will': 509,
#  'eléctrico': 510,
#  'és': 511,
#  'información': 512,
#  'aborto': 513,
#  'Libertad': 514,
#  'responsable': 515,
#  'asesinado': 516,
#  'Covid': 517,
#  'condenar': 518,
#  'twitcheada': 519,
#  'asesinar': 520,
#  'frontera': 521,
#  'especialmente': 522,
#  'Carlos': 523,
#  'ánimo': 524,
#  'caro': 525,
#  'ataque': 526,
#  'traer': 527,
#  'comunista': 528,
#  'sostenible': 529,
#  'terminar': 530,
#  'acción': 531,
#  'atrás': 532,
#  'criticar': 533,
#  'falso': 534,
#  'opinión': 535,
#  'generación': 536,
#  'alegría': 537,
#  'be': 538,
#  'necesitado': 539,
#  'Moncloa': 540,
#  'digital': 541,
#  'familiar': 542,
#  'agosto': 543,
#  'ilegal': 544,
#  'delito': 545,
#  'reforzar': 546,
#  'Consejo': 547,
#  'relación': 548,
#  'preguntar': 549,
#  'desear': 550,
#  'base': 551,
#  'virus': 552,
#  'líder': 553,
#  'are': 554,
#  'década': 555,
#  'hilo': 556,
#  'meter': 557,
#  'capaz': 558,
#  'conseguir': 559,
#  'allá': 560,
#  'turismo': 561,
#  'capital': 562,
#  'rico': 563,
#  'Iglesias': 564,
#  'nacer': 565,
#  'sede': 566,
#  'imagen': 567,
#  'prueba': 568,
#  'dosis': 569,
#  'alquiler': 570,
#  'producir': 571,
#  'consecuencia': 572,
#  'Pueblo': 573,
#  'hacer él': 574,
#  'gana': 575,
#  'curso': 576,
#  'protección': 577,
#  'golpe': 578,
#  'oro': 579,
#  'costar': 580,
#  'prioridad': 581,
#  'presente': 582,
#  'vencer': 583,
#  'enlace': 584,
#  'g': 585,
#  'amor': 586,
#  'parecer': 587,
#  'actuar': 588,
#  'guerra': 589,
#  'viernes': 590,
#  'unido': 591,
#  'tarifa': 592,
#  'motivo': 593,
#  'coste': 594,
#  'by': 595,
#  'Marruecos': 596,
#  'duda': 597,
#  'régimen': 598,
#  'deuda': 599,
#  'Plan': 600,
#  'golpista': 601,
#  'vacunar': 602,
#  'mentir': 603,
#  'encuentro': 604,
#  'continuar': 605,
#  'cárcel': 606,
#  'vergüenza': 607,
#  'romper': 608,
#  'planeta': 609,
#  'aprender': 610,
#  'soberanía': 611,
#  'agua': 612,
#  'retirar': 613,
#  'viva': 614,
#  'I': 615,
#  'Rey': 616,
#  'señor': 617,
#  'dignidad': 618,
#  'principio': 619,
#  'respetar': 620,
#  'papel': 621,
#  'financiar': 622,
#  'Partido': 623,
#  'anunciar': 624,
#  'afectar': 625,
#  'civil': 626,
#  'alcalde': 627,
#  'lleno': 628,
#  'efecto': 629,
#  'bonito': 630,
#  'amenaza': 631,
#  'urgente': 632,
#  'voz': 633,
#  'imponer': 634,
#  'fácil': 635,
#  'mierda': 636,
#  'mesa': 637,
#  'eléctrica': 638,
#  'support': 639,
#  'puerta': 640,
#  'imprescindible': 641,
#  'acompañar': 642,
#  'pequeño': 643,
#  'condena': 644,
#  'Constitucional': 645,
#  'consumo': 646,
#  'muerto': 647,
#  'trans': 648,
#  'robar': 649,
#  'actual': 650,
#  'experiencia': 651,
#  'terrorista': 652,
#  'preocupar': 653,
#  'dar él': 654,
#  'grave': 655,
#  'afectado': 656,
#  'bloquear': 657,
#  'ETA': 658,
#  'terrible': 659,
#  'aportar': 660,
#  'ver él': 661,
#  'asumir': 662,
#  'destruir': 663,
#  'ojalá': 664,
#  'candidatura': 665,
#  'juego': 666,
#  'crecimiento': 667,
#  'Presidente': 668,
#  'all': 669,
#  'acoger': 670,
#  'absoluto': 671,
#  'bienestar': 672,
#  'saludo': 673,
#  'ministra': 674,
#  'recomendar': 675,
#  'hola': 676,
#  'Dios': 677,
#  'mascarilla': 678,
#  'q': 679,
#  'liderar': 680,
#  'publicar': 681,
#  't': 682,
#  'Popular': 683,
#  'número': 684,
#  'señalar': 685,
#  'today': 686,
#  'máis': 687,
#  'rechazar': 688,
#  'ilusión': 689,
#  'energético': 690,
#  'batalla': 691,
#  'comunicación': 692,
#  'tratar': 693,
#  'reunir': 694,
#  'riesgo': 695,
#  'referente': 696,
#  'invitar': 697,
#  'Fernando': 698,
#  'non': 699,
#  'principal': 700,
#  'iniciativa': 701,
#  'Social': 702,
#  'autonómico': 703,
#  'iniciar': 704,
#  'Bravo': 705,
#  'investigar': 706,
#  'Mar': 707,
#  'recuerdo': 708,
#  'judicial': 709,
#  'preparar': 710,
#  'Real': 711,
#  'negocio': 712,
#  'resultado': 713,
#  'vuelta': 714,
#  'aprovechar': 715,
#  'mundial': 716,
#  'lanzar': 717,
#  'cabeza': 718,
#  'abandonar': 719,
#  'parar': 720,
#  'Europea': 721,
#  'convivencia': 722,
#  'duro': 723,
#  'colaboración': 724,
#  'afiliado': 725,
#  'insultar': 726,
#  'socio': 727,
#  'interesar': 728,
#  'oferta': 729,
#  'julio': 730,
#  'asesino': 731,
#  'solidario': 732,
#  'alarma': 733,
#  'pena': 734,
#  'carne': 735,
#  'serio': 736,
#  'Biden': 737,
#  'invertir': 738,
#  'marcar': 739,
#  'televisión': 740,
#  'Twitter': 741,
#  'Francia': 742,
#  'that': 743,
#  'preferir': 744,
#  'conjunto': 745,
#  'serie': 746,
#  'quitar': 747,
#  'ocurrir': 748,
#  'enhorabuenir': 749,
#  'actividad': 750,
#  'declaración': 751,
#  'patrimonio': 752,
#  'pobre': 753,
#  'vegan': 754,
#  'pregunta': 755,
#  'EditorialLR': 756,
#  'siglo': 757,
#  'lista': 758,
#  'terrorismo': 759,
#  'esencial': 760,
#  'militar': 761,
#  'diseño': 762,
#  'it': 763,
#  'security': 764,
#  'Supremo': 765,
#  'Antonio': 766,
#  'acudir': 767,
#  'María': 768,
#  'des': 769,
#  'estrategia': 770,
#  'próximo': 771,
#  'cuerpo': 772,
#  'puesto': 773,
#  'talento': 774,
#  'junio': 775,
#  'emergencia': 776,
#  'independencia': 777,
#  'at': 778,
#  'ridículo': 779,
#  'silencio': 780,
#  'periodismo': 781,
#  'central': 782,
#  'sentencia': 783,
#  'nación': 784,
#  'reivindicar': 785,
#  'vulnerable': 786,
#  'alimento': 787,
#  'comercio': 788,
#  'contrario': 789,
#  'error': 790,
#  'abierto': 791,
#  'ampliar': 792,
#  'mediático': 793,
#  'institucional': 794,
#  'afrontar': 795,
#  'ayudar yo': 796,
#  'avance': 797,
#  'imaginar': 798,
#  'confianza': 799,
#  'vender': 800,
#  'sábado': 801,
#  'CGPJ': 802,
#  'cierre': 803,
#  'atender': 804,
#  'prensa': 805,
#  'convocar': 806,
#  'incluir': 807,
#  'ciudadanía': 808,
#  'corrupción': 809,
#  'crimen': 810,
#  'nuclear': 811,
#  'corrupto': 812,
#  'sexual': 813,
#  'crítica': 814,
#  'sitio': 815,
#  'depender': 816,
#  'bloqueo': 817,
#  'mental': 818,
#  'explotación': 819,
#  'Menor': 820,
#  'Sanidad': 821,
#  'new': 822,
#  'intentar': 823,
#  'argumento': 824,
#  'magnífico': 825,
#  'desarrollo': 826,
#  'inmenso': 827,
#  'artista': 828,
#  'llenar': 829,
#  'rendir': 830,
#  'García': 831,
#  'Luis': 832,
#  'tremendo': 833,
#  'extraordinario': 834,
#  'diputado': 835,
#  'candidato': 836,
#  'puto': 837,
#  'Carmen': 838,
#  'Alberto': 839,
#  'incendio': 840,
#  'capitalismo': 841,
#  'normalidad': 842,
#  'amiga': 843,
#  'movimiento': 844,
#  'rey': 845,
#  'dedicar': 846,
#  'asunto': 847,
#  'declarar': 848,
#  'ojo': 849,
#  'comprometido': 850,
#  'independentista': 851,
#  'educativo': 852,
#  'Foreign': 853,
#  'tienda': 854,
#  'concordia': 855,
#  'progresista': 856,
#  'na': 857,
#  'línea': 858,
#  'cita': 859,
#  'distinto': 860,
#  'hem': 861,
#  'felicidad': 862,
#  'hecho': 863,
#  'lunes': 864,
#  'SMI': 865,
#  'material': 866,
#  'negro': 867,
#  'producción': 868,
#  'inmediato': 869,
#  'impedir': 870,
#  'combatir': 871,
#  'informe': 872,
#  'creación': 873,
#  'Montero': 874,
#  'región': 875,
#  'municipal': 876,
#  'venezolano': 877,
#  'provocar': 878,
#  'aniversario': 879,
#  'encantar': 880,
#  'organización': 881,
#  'podrer': 882,
#  'transición': 883,
#  'inmigración': 884,
#  'vivo': 885,
#  'camiseta': 886,
#  'promover': 887,
#  'tiempo': 888,
#  'difundir': 889,
#  'cuidado': 890,
#  'Colombia': 891,
#  'controlar': 892,
#  'Unión': 893,
#  'positivo': 894,
#  'preparado': 895,
#  'Argentina': 896,
#  'agresión': 897,
#  'causa': 898,
#  'agradecimiento': 899,
#  'vacación': 900,
#  'ola': 901,
#  'cubano': 902,
#  'criminal': 903,
#  'people': 904,
#  'callar': 905,
#  'suficiente': 906,
#  'comunismo': 907,
#  'reclamar': 908,
#  'Lorca': 909,
#  'humanos': 910,
#  'derechos': 911,
#  'existir': 912,
#  'CCAA': 913,
#  'escuela': 914,
#  'Juegos': 915,
#  'é': 916,
#  'mitad': 917,
#  'interesante': 918,
#  'web': 919,
#  'aplicar': 920,
#  'recurrir': 921,
#  'científico': 922,
#  'excelente': 923,
#  'aparecer': 924,
#  'imposible': 925,
#  'ecológico': 926,
#  'propiedad': 927,
#  'from': 928,
#  'descubrir': 929,
#  'cómplice': 930,
#  'canción': 931,
#  'com': 932,
#  'industria': 933,
#  'constitucional': 934,
#  'visita': 935,
#  'intervenir': 936,
#  'provincia': 937,
#  'á': 938,
#  'competencia': 939,
#  'resultar': 940,
#  'jamás': 941,
#  'obrero': 942,
#  'empresario': 943,
#  'semanal': 944,
#  'Unidas': 945,
#  'contribuir': 946,
#  'jueves': 947,
#  'ultraderecha': 948,
#  'apuesta': 949,
#  'als': 950,
#  'diario': 951,
#  'financiación': 952,
#  'acceso': 953,
#  'progres': 954,
#  'Vallecas': 955,
#  'felicidades': 956,
#  'Murcia': 957,
#  'huelga': 958,
#  'consumidor': 959,
#  'peligro': 960,
#  'significar': 961,
#  'plaza': 962,
#  'estabilidad': 963,
#  'Alemania': 964,
#  'acercar': 965,
#  'privilegio': 966,
#  'separatismo': 967,
#  'important': 968,
#  'análisis': 969,
#  'socialismo': 970,
#  'entrada': 971,
#  'pauta': 972,
#  'aeropuerto': 973,
#  'nazi': 974,
#  'legado': 975,
#  'etapa': 976,
#  'debatir': 977,
#  'NiUnaMenos': 978,
#  'Bitcoin': 979,
#  'patriota': 980,
#  'diferencia': 981,
#  'maravilla': 982,
#  'ocultar': 983,
#  'unha': 984,
#  'hermano': 985,
#  'prisión': 986,
#  'pacto': 987,
#  'Felipe': 988,
#  'facilitar': 989,
#  'asociación': 990,
#  'an': 991,
#  'ens': 992,
#  'have': 993,
#  'popular': 994,
#  'obligación': 995,
#  'animar': 996,
#  'lujo': 997,
#  'arte': 998,
#  'amar': 999,
#  ...}

# %%
with open('data_tokenized.pickle', 'rb') as handle:
    tokenized_data = pickle.load(handle)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5763/3325641071.py in <module>
# ----> 1 with open('data_tokenized.pickle', 'rb') as handle:
#       2     tokenized_data = pickle.load(handle)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data_tokenized.pickle'
